# %% [markdown]
# <a href="https://colab.research.google.com/github/sonali810/BMEN-6367-AI-in-Biomedical-Engineering/blob/main/BMEN6367_SonaliGandhi_Homework2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Google Account, Google Drive, and Github Account

# %% [markdown]
# ## Github Account: https://github.com/sonali810
# ## Google Drive / Google Account : ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Integrating Colab with Google Drive and Github

# %% [markdown]
# ## I linked Colab with GitHub and created a repository housing homework assignments as an example: ![image.png](data:image/png;base64,...)
#
# ## Files within Google Drive or GitHub can be accessed by: ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Access to Google Drive Content can be given by the following lines of code:

# %%
from google.colab import drive

drive.mount('/content/drive') # Allows access to google drive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Low Pass Filter on Image from Google Drive

# %%
from google.colab import drive
import matplotlib.pyplot as plt
from scipy import ndimage

drive.mount('/content/drive') # Allows access to google drive
image_path = '/content/drive/My Drive/Images/Noisy.JPG' # Establishes the image's pathway in drive
img = plt.imread(image_path) # Reads the image path
plt.subplot(2, 2, 1) # Creates a subplot made up of 2 images
plt.title('Original Image')
plt.axis('off')  # Turn off axis numbers and ticks
plt.imshow(img) # Displays the image

sigma = 4.0
# Apply the Gaussian filter
filtered_image = ndimage.gaussian_filter(img, sigma=sigma)

# Display the filtered image
plt.subplot(2, 2, 2)
plt.imshow(filtered_image, cmap = 'gray') # Displays the filtered image in grey
plt.title('Filtered Image (Low-Pass Filter)')
plt.axis('off')
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Image Explanation

# %% [markdown]
# ### The results of this code displays a gray filtered image that has a blurring effect. This is because the Gaussian filter averages the value of the neighboring pixels, causing this blurring effect. The Gaussian filter is a low-pass filter because it removes the high-frequency components of the image when it takes the average of the pixels.

# %% [markdown]
# # Median Filter on Image from Google Drive

# %%
from google.colab import drive
import matplotlib.pyplot as plt
from scipy import ndimage

drive.mount('/content/drive') # Allows access to google drive
image_path = '/content/drive/My Drive/Images/SaltandPepper.JPG' # Establishes the image's pathway in drive
img = plt.imread(image_path) # Reads the image path
plt.subplot(2, 2, 1) # Creates a subplot made up of 2 images
plt.title('Original Image')
plt.axis('off')  # Turn off axis numbers and ticks
plt.imshow(img)

# Applies the median filter
filtered_image = ndimage.median_filter(img, size=5)

# Display the filtered image
plt.subplot(2, 2, 2)
plt.imshow(filtered_image, cmap = 'gray') # Displays the filtered image in gray
plt.title('Filtered Image (Median Filter)')
plt.axis('off')
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Image Explanation

# %% [markdown]
# ### The results of this code displays a new picture that reduces the effects of the "white specks" that are seen on the original filter using the median filter. The median filter replaces each pixel value in the image with the median value of its neighboring pixels. This filter does not blur the image as much as other filters because it preserves the edges of the image. The 'kernel size' of the filter establishes how much noise will be removed from the original image. The larger the kernel size, the more noise will be removed from the image. However, as more noise is removed, the images becomes more blurred. The median filter is effective when removing 'salt and pepper' and impulse noise.
